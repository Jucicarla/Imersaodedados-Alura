# %% [markdown]
# <a href="https://colab.research.google.com/github/Jucicarla/Imersaodedados-Alura/blob/main/imersaodados1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Imersão Dados Alura - Aula 1:**
#
# **Análise da dados, Python, pandas e Genética - para atacar um problema**

# %%
import pandas as pd

url_dados = "https://github.com/Jucicarla/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"

dados= pd.read_csv(url_dados, compression='zip')

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
#retorna o tamanho da dataset
dados.shape
# Out:
# (23814, 877)

# %% [markdown]
# Analisando os dados

# %%
#serie de conjunto de dados
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
#tempo que a droga age
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
#dois tipos de dose
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
#descobrir quais elemento g0 sao maiores que 0.
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 01: Investigar por que a classe tratamento é tão desbalanceda?
#
# ###Dasafio 02: Plotar as 5 ultimas linhas da tabela
#
# ###Desafio 03: Proporção das classes tratamento
#
# ###Desafio04: Quantas tipo de drogas foram investigados
#
# ###Desafio 05: Procurar na documentação o metodo query(pandas)
#
# ###Desafio 06 : renomear as colunas tirando o hífen.
# ###Desafio 07: Deixar os grafico bonitões.(Matplotli.pyplot)
#
# ##Desafio 08: Resumo do que você aprendeu com os dados

# %%
#Desafio 01: Investigar por que a classe tratamento é tão desbalanceda?
dados['tratamento'].value_counts()
#houve mais tratamento com o uso de droga
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
#Desafio 02: Plotar as 5 ultimas linhas da tabela
#uso do tail(), retorna as ultimas 5 linhas
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
#Desafio 03: Proporção das classes tratamento
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
#Desafio04: Quantos tipo de drogas foram investigados
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# ae2afcf9d       1
# d70cdde82       1
# b046f598b       1
# 32dccc366       1
# b36078dd2       1
# Name: droga, Length: 3289, dtype: int64

# %%
#Desafio 05: Procurar na documentação o metodo query(pandas)
#query consultar e filtrar os dados, usamos os operadores lógicos AND(&) e OR( | ) e 
#expressões lógicas (==, != , >, <, >= e <=), achei bem simples
dados.query('tempo == 24')
# Out:
#                  id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 5      id_001762a82  com_droga     24   D1  ...  1.2120  0.3765  0.7848  1.3990
# 6      id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 17     id_0031dd989  com_droga     24   D2  ...  0.8093 -0.0269  0.4259  0.9279
# 32     id_006e27d96  com_droga     24   D2  ...  0.0691  0.1536  0.2948 -0.9860
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23802  id_fff3976bd  com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23804  id_fff506720  com_droga     24   D1  ... -0.4097  0.2282 -0.3213 -0.0836
# 23809  id_fffb1ceed  com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c  com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23812  id_fffcb9e7c  com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
#
# ...

# %%
#Desafio 06 : renomear as colunas tirando o hífen.

#mostrar todas as colunas
dados.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g-0', 'g-1', 'g-2',
#        'g-3', 'g-4',
#        ...
#        'c-90', 'c-91', 'c-92', 'c-93', 'c-94', 'c-95', 'c-96', 'c-97', 'c-98',
#        'c-99'],
#       dtype='object', length=877)

# %%
#renomeando
# replace() é o responsável por essa remoção

dados.columns = dados.columns.str.replace('-', '')
dados.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g0', 'g1', 'g2', 'g3',
#        'g4',
#        ...
#        'c90', 'c91', 'c92', 'c93', 'c94', 'c95', 'c96', 'c97', 'c98', 'c99'],
#       dtype='object', length=877)

# %%
#dados sem o hifen
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
#Desafio 07: Deixar os grafico bonitões.(Matplotli.pyplot)
dados['tratamento'].value_counts().plot.pie(x = 'Tipo de Tratamento', figsize = (8,8), title='Gráfico de Pizza - Tratamento',
                                            labels=['Com Droga', 'Com Controle'], colors=['green','c'], autopct="%.2f", fontsize=20)

# %%
dados['tempo'].value_counts().plot.bar(title= 'Gráfico de Barras - Tempo',x = 'tempo',
                                       y='experimentos', figsize = (15,5), rot = 0,
                                       )

# %% [markdown]
# ##Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# - O dataset possui 23814 linhas e  877 colunas, contendo dados de experimentos.
# - cada uso de droga vai ter um tempo para agir, que varia de 24, 72 ou 48 horas.
# - Uso de tratamento de controle com droga mostra o uso de 92,16% de todo o dataset.
# - Foram realizados 3289 experimentos com o uso de diversas drogas.
